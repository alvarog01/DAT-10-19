# %% [markdown]
# ### Connecting Pandas to a Database
#
# This notebook will walk us through how to use pandas to interact with a database, and then query an API and add new values to it.
#
# Running this code continuously will allow us to programmatically collect a unique data source.

# %%
import pandas as pd
import numpy as np
# you will need to import this -- pip install SQLAlchemy
from sqlalchemy import create_engine, types
# you will need to import this -- pip install mysql-connector-python
import mysql.connector
import requests
# you will need to install this  -- pip install requests-oauthlib
from requests_oauthlib import OAuth1

# %% [markdown]
# ### Step 1:  Fetching the Data From the Database

# %%
# we'll create a dictionary to store all of our database information
df_dict = {
    'connector': 'mysql+mysqlconnector',
    'username' : 'dat1019',
    'password' : 'dat1019password',
    'server'   : 'dat-10-19.cfvn8ddij95j.us-east-1.rds.amazonaws.com',
    'port'     : '3306',
    'database' : 'dat1019'
}

# %%
df_dict['connector']
# Out:
# 'mysql+mysqlconnector'

# %%
# this string contains all the information
connection_string = f"{df_dict['connector']}://{df_dict['username']}:{df_dict['password']}@{df_dict['server']}:{df_dict['port']}/{df_dict['database']}"

# %%
connection_string
# Out:
# 'mysql+mysqlconnector://dat1019:dat1019password@dat-10-19.cfvn8ddij95j.us-east-1.rds.amazonaws.com:3306/dat1019'

# %%
# this is what we need to connect to our database
engine = create_engine(connection_string)

# %%
# we'll now connect to the database and pull in the info
with engine.connect() as connection:
    tweets = pd.read_sql_query("SELECT * FROM tweets", con=connection)

# %%
# let's look at our results
tweets.head()
# Out:
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  RT @realDonaldTrump: VOTE! VOTE! VOTE!\nhttps:...    117124          0
# 1                            https://t.co/zX4bqgtWqH     10186      47177
# 2                            https://t.co/SMaOF79kPV     10806      44040
# 3  RT @BarstoolNewsN: The Amish are not playing a...     17887          0
# 4  A parade for me in Nigeria, a great honor! htt...     39398     199959
#
#                     id
# 0  1323692146147340299
# 1  1323692020880297986
# 2  1323691984989622272
# 3  1323684790894297089
# 4  1323680963310866435

# %%
# we will turn this column into a string -- useful for later processing
tweets['id'] = tweets.id.astype(str)

# %% [markdown]
# ### Step 2:  Getting API Data

# %%
# authorization information for the Twitter API
tokens = OAuth1('NOZHm1aLT1AVmchGbCmiZOAga', 'nPyaYCt8L7ymqGZtU8EqC0a2ypI9aSJgVNIhtoZ0wGsaf3BJw9',
                '1079981876864008192-AlhO4yOa06oW2sXZpLpWPwnOxEERYS', 'o3E0AsKJfDoTBk77UQYExzOG7E46jPYvpWNGAKsD6lUBY')

# %%
# the api endpoint we'll ping to get our API results
base_url = 'https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=realDonaldTrump&count=200'

# %%
# this is our list of dictionaries that contains Donald Trump's tweets
tweet_results = requests.get(base_url, auth=tokens).json()

# %%
# here's our resulting dictionary
pd.DataFrame(tweet_results[6])
# Out:
#                                                         created_at  \
# hashtags                            Fri Dec 18 14:14:32 +0000 2020
# symbols                             Fri Dec 18 14:14:32 +0000 2020
# user_mentions                       Fri Dec 18 14:14:32 +0000 2020
# urls                                Fri Dec 18 14:14:32 +0000 2020
# id                                  Fri Dec 18 14:14:32 +0000 2020
# id_str                              Fri Dec 18 14:14:32 +0000 2020
# name                                Fri Dec 18 14:14:32 +0000 2020
# screen_name                         Fri Dec 18 14:14:32 +0000 2020
# location                            Fri Dec 18 14:14:32 +0000 2020
# description                         Fri Dec 18 14:14:32 +0000 2020
# url                                 Fri Dec 18 14:14:32 +0000 2020
# entities                            Fri Dec 18 14:14:32 +0000 2020
# protected                           Fri Dec 18 14:14:32 +0000 2020
# followers_count                     Fri Dec 18 14:14:32 +0000 2020
# friends_count                       Fri Dec 18 14:14:32 +0000 2020
# listed_count                        Fri Dec 18 14:14:32 +0000 2020
# created_at                          Fri Dec 18 14:14:32 +0000 2020
# favourites_count                    Fri Dec 18 14:14:32 +0000 2020
# utc_offset                          Fri Dec 18 14:14:32 +0000 2020
# time_zone                           Fri Dec 18 14:14:32 +0000 2020
# geo_enabled                         Fri Dec 18 14:14:32 +0000 2020
# verified                            Fri Dec 18 14:14:32 +0000 2020
# statuses_count                      Fri Dec 18 14:14:32 +0000 2020
# lang                                Fri Dec 18 14:14:32 +0000 2020
# contributors_enabled                Fri Dec 18 14:14:32 +0000 2020
# is_translator                       Fri Dec 18 14:14:32 +0000 2020
# is_translation_enabled              Fri Dec 18 14:14:32 +0000 2020
# profile_background_color            Fri Dec 18 14:14:32 +0000 2020
# profile_background_image_url        Fri Dec 18 14:14:32 +0000 2020
# profile_background_image_url_https  Fri Dec 18 14:14:32 +0000 2020
# profile_background_tile             Fri Dec 18 14:14:32 +0000 2020
# profile_image_url                   Fri Dec 18 14:14:32 +0000 2020
# profile_image_url_https             Fri Dec 18 14:14:32 +0000 2020
# profile_banner_url                  Fri Dec 18 14:14:32 +0000 2020
# profile_link_color                  Fri Dec 18 14:14:32 +0000 2020
# profile_sidebar_border_color        Fri Dec 18 14:14:32 +0000 2020
# profile_sidebar_fill_color          Fri Dec 18 14:14:32 +0000 2020
# profile_text_color                  Fri Dec 18 14:14:32 +0000 2020
# profile_use_background_image        Fri Dec 18 14:14:32 +0000 2020
# has_extended_profile                Fri Dec 18 14:14:32 +0000 2020
# default_profile                     Fri Dec 18 14:14:32 +0000 2020
# default_profile_image               Fri Dec 18 14:14:32 +0000 2020
# following                           Fri Dec 18 14:14:32 +0000 2020
# follow_request_sent                 Fri Dec 18 14:14:32 +0000 2020
# notifications                       Fri Dec 18 14:14:32 +0000 2020
# translator_type                     Fri Dec 18 14:14:32 +0000 2020
#
#                                                      id               id_str  \
# hashtags                            1339937091707351046  1339937091707351046
# symbols                             1339937091707351046  1339937091707351046
# user_mentions                       1339937091707351046  1339937091707351046
# urls                                1339937091707351046  1339937091707351046
# id                                  1339937091707351046  1339937091707351046
# id_str                              1339937091707351046  1339937091707351046
# name                                1339937091707351046  1339937091707351046
# screen_name                         1339937091707351046  1339937091707351046
# location                            1339937091707351046  1339937091707351046
# description                         1339937091707351046  1339937091707351046
# url                                 1339937091707351046  1339937091707351046
# entities                            1339937091707351046  1339937091707351046
# protected                           1339937091707351046  1339937091707351046
# followers_count                     1339937091707351046  1339937091707351046
# friends_count                       1339937091707351046  1339937091707351046
# listed_count                        1339937091707351046  1339937091707351046
# created_at                          1339937091707351046  1339937091707351046
# favourites_count                    1339937091707351046  1339937091707351046
# utc_offset                          1339937091707351046  1339937091707351046
# time_zone                           1339937091707351046  1339937091707351046
# geo_enabled                         1339937091707351046  1339937091707351046
# verified                            1339937091707351046  1339937091707351046
# statuses_count                      1339937091707351046  1339937091707351046
# lang                                1339937091707351046  1339937091707351046
# contributors_enabled                1339937091707351046  1339937091707351046
# is_translator                       1339937091707351046  1339937091707351046
# is_translation_enabled              1339937091707351046  1339937091707351046
# profile_background_color            1339937091707351046  1339937091707351046
# profile_background_image_url        1339937091707351046  1339937091707351046
# profile_background_image_url_https  1339937091707351046  1339937091707351046
# profile_background_tile             1339937091707351046  1339937091707351046
# profile_image_url                   1339937091707351046  1339937091707351046
# profile_image_url_https             1339937091707351046  1339937091707351046
# profile_banner_url                  1339937091707351046  1339937091707351046
# profile_link_color                  1339937091707351046  1339937091707351046
# profile_sidebar_border_color        1339937091707351046  1339937091707351046
# profile_sidebar_fill_color          1339937091707351046  1339937091707351046
# profile_text_color                  1339937091707351046  1339937091707351046
# profile_use_background_image        1339937091707351046  1339937091707351046
# has_extended_profile                1339937091707351046  1339937091707351046
# default_profile                     1339937091707351046  1339937091707351046
# default_profile_image               1339937091707351046  1339937091707351046
# following                           1339937091707351046  1339937091707351046
# follow_request_sent                 1339937091707351046  1339937091707351046
# notifications                       1339937091707351046  1339937091707351046
# translator_type                     1339937091707351046  1339937091707351046
#
#                                                                                  text  \
# hashtags                            .@senatemajldr and Republican Senators have to...
# symbols                             .@senatemajldr and Republican Senators have to...
# user_mentions                       .@senatemajldr and Republican Senators have to...
# urls                                .@senatemajldr and Republican Senators have to...
# id                                  .@senatemajldr and Republican Senators have to...
# id_str                              .@senatemajldr and Republican Senators have to...
# name                                .@senatemajldr and Republican Senators have to...
# screen_name                         .@senatemajldr and Republican Senators have to...
# location                            .@senatemajldr and Republican Senators have to...
# description                         .@senatemajldr and Republican Senators have to...
# url                                 .@senatemajldr and Republican Senators have to...
# entities                            .@senatemajldr and Republican Senators have to...
# protected                           .@senatemajldr and Republican Senators have to...
# followers_count                     .@senatemajldr and Republican Senators have to...
# friends_count                       .@senatemajldr and Republican Senators have to...
# listed_count                        .@senatemajldr and Republican Senators have to...
# created_at                          .@senatemajldr and Republican Senators have to...
# favourites_count                    .@senatemajldr and Republican Senators have to...
# utc_offset                          .@senatemajldr and Republican Senators have to...
# time_zone                           .@senatemajldr and Republican Senators have to...
# geo_enabled                         .@senatemajldr and Republican Senators have to...
# verified                            .@senatemajldr and Republican Senators have to...
# statuses_count                      .@senatemajldr and Republican Senators have to...
# lang                                .@senatemajldr and Republican Senators have to...
# contributors_enabled                .@senatemajldr and Republican Senators have to...
# is_translator                       .@senatemajldr and Republican Senators have to...
# is_translation_enabled              .@senatemajldr and Republican Senators have to...
# profile_background_color            .@senatemajldr and Republican Senators have to...
# profile_background_image_url        .@senatemajldr and Republican Senators have to...
# profile_background_image_url_https  .@senatemajldr and Republican Senators have to...
# profile_background_tile             .@senatemajldr and Republican Senators have to...
# profile_image_url                   .@senatemajldr and Republican Senators have to...
# profile_image_url_https             .@senatemajldr and Republican Senators have to...
# profile_banner_url                  .@senatemajldr and Republican Senators have to...
# profile_link_color                  .@senatemajldr and Republican Senators have to...
# profile_sidebar_border_color        .@senatemajldr and Republican Senators have to...
# profile_sidebar_fill_color          .@senatemajldr and Republican Senators have to...
# profile_text_color                  .@senatemajldr and Republican Senators have to...
# profile_use_background_image        .@senatemajldr and Republican Senators have to...
# has_extended_profile                .@senatemajldr and Republican Senators have to...
# default_profile                     .@senatemajldr and Republican Senators have to...
# default_profile_image               .@senatemajldr and Republican Senators have to...
# following                           .@senatemajldr and Republican Senators have to...
# follow_request_sent                 .@senatemajldr and Republican Senators have to...
# notifications                       .@senatemajldr and Republican Senators have to...
# translator_type                     .@senatemajldr and Republican Senators have to...
#
#                                     truncated  \
# hashtags                                 True
# symbols                                  True
# user_mentions                            True
# urls                                     True
# id                                       True
# id_str                                   True
# name                                     True
# screen_name                              True
# location                                 True
# description                              True
# url                                      True
# entities                                 True
# protected                                True
# followers_count                          True
# friends_count                            True
# listed_count                             True
# created_at                               True
# favourites_count                         True
# utc_offset                               True
# time_zone                                True
# geo_enabled                              True
# verified                                 True
# statuses_count                           True
# lang                                     True
# contributors_enabled                     True
# is_translator                            True
# is_translation_enabled                   True
# profile_background_color                 True
# profile_background_image_url             True
# profile_background_image_url_https       True
# profile_background_tile                  True
# profile_image_url                        True
# profile_image_url_https                  True
# profile_banner_url                       True
# profile_link_color                       True
# profile_sidebar_border_color             True
# profile_sidebar_fill_color               True
# profile_text_color                       True
# profile_use_background_image             True
# has_extended_profile                     True
# default_profile                          True
# default_profile_image                    True
# following                                True
# follow_request_sent                      True
# notifications                            True
# translator_type                          True
#
#                                                                              entities  \
# hashtags                                                                           []
# symbols                                                                            []
# user_mentions                       [{'screen_name': 'senatemajldr', 'name': 'Lead...
# urls                                [{'url': 'https://t.co/T6EClLu3OY', 'expanded_...
# id                                                                                NaN
# id_str                                                                            NaN
# name                                                                              NaN
# screen_name                                                                       NaN
# location                                                                          NaN
# description                                                                       NaN
# url                                                                               NaN
# entities                                                                          NaN
# protected                                                                         NaN
# followers_count                                                                   NaN
# friends_count                                                                     NaN
# listed_count                                                                      NaN
# created_at                                                                        NaN
# favourites_count                                                                  NaN
# utc_offset                                                                        NaN
# time_zone                                                                         NaN
# geo_enabled                                                                       NaN
# verified                                                                          NaN
# statuses_count                                                                    NaN
# lang                                                                              NaN
# contributors_enabled                                                              NaN
# is_translator                                                                     NaN
# is_translation_enabled                                                            NaN
# profile_background_color                                                          NaN
# profile_background_image_url                                                      NaN
# profile_background_image_url_https                                                NaN
# profile_background_tile                                                           NaN
# profile_image_url                                                                 NaN
# profile_image_url_https                                                           NaN
# profile_banner_url                                                                NaN
# profile_link_color                                                                NaN
# profile_sidebar_border_color                                                      NaN
# profile_sidebar_fill_color                                                        NaN
# profile_text_color                                                                NaN
# profile_use_background_image                                                      NaN
# has_extended_profile                                                              NaN
# default_profile                                                                   NaN
# default_profile_image                                                             NaN
# following                                                                         NaN
# follow_request_sent                                                               NaN
# notifications                                                                     NaN
# translator_type                                                                   NaN
#
#                                                                                source  \
# hashtags                            <a href="http://twitter.com/download/iphone" r...
# symbols                             <a href="http://twitter.com/download/iphone" r...
# user_mentions                       <a href="http://twitter.com/download/iphone" r...
# urls                                <a href="http://twitter.com/download/iphone" r...
# id                                  <a href="http://twitter.com/download/iphone" r...
# id_str                              <a href="http://twitter.com/download/iphone" r...
# name                                <a href="http://twitter.com/download/iphone" r...
# screen_name                         <a href="http://twitter.com/download/iphone" r...
# location                            <a href="http://twitter.com/download/iphone" r...
# description                         <a href="http://twitter.com/download/iphone" r...
# url                                 <a href="http://twitter.com/download/iphone" r...
# entities                            <a href="http://twitter.com/download/iphone" r...
# protected                           <a href="http://twitter.com/download/iphone" r...
# followers_count                     <a href="http://twitter.com/download/iphone" r...
# friends_count                       <a href="http://twitter.com/download/iphone" r...
# listed_count                        <a href="http://twitter.com/download/iphone" r...
# created_at                          <a href="http://twitter.com/download/iphone" r...
# favourites_count                    <a href="http://twitter.com/download/iphone" r...
# utc_offset                          <a href="http://twitter.com/download/iphone" r...
# time_zone                           <a href="http://twitter.com/download/iphone" r...
# geo_enabled                         <a href="http://twitter.com/download/iphone" r...
# verified                            <a href="http://twitter.com/download/iphone" r...
# statuses_count                      <a href="http://twitter.com/download/iphone" r...
# lang                                <a href="http://twitter.com/download/iphone" r...
# contributors_enabled                <a href="http://twitter.com/download/iphone" r...
# is_translator                       <a href="http://twitter.com/download/iphone" r...
# is_translation_enabled              <a href="http://twitter.com/download/iphone" r...
# profile_background_color            <a href="http://twitter.com/download/iphone" r...
# profile_background_image_url        <a href="http://twitter.com/download/iphone" r...
# profile_background_image_url_https  <a href="http://twitter.com/download/iphone" r...
# profile_background_tile             <a href="http://twitter.com/download/iphone" r...
# profile_image_url                   <a href="http://twitter.com/download/iphone" r...
# profile_image_url_https             <a href="http://twitter.com/download/iphone" r...
# profile_banner_url                  <a href="http://twitter.com/download/iphone" r...
# profile_link_color                  <a href="http://twitter.com/download/iphone" r...
# profile_sidebar_border_color        <a href="http://twitter.com/download/iphone" r...
# profile_sidebar_fill_color          <a href="http://twitter.com/download/iphone" r...
# profile_text_color                  <a href="http://twitter.com/download/iphone" r...
# profile_use_background_image        <a href="http://twitter.com/download/iphone" r...
# has_extended_profile                <a href="http://twitter.com/download/iphone" r...
# default_profile                     <a href="http://twitter.com/download/iphone" r...
# default_profile_image               <a href="http://twitter.com/download/iphone" r...
# following                           <a href="http://twitter.com/download/iphone" r...
# follow_request_sent                 <a href="http://twitter.com/download/iphone" r...
# notifications                       <a href="http://twitter.com/download/iphone" r...
# translator_type                     <a href="http://twitter.com/download/iphone" r...
#
#                                    in_reply_to_status_id  \
# hashtags                                            None
# symbols                                             None
# user_mentions                                       None
# urls                                                None
# id                                                  None
# id_str                                              None
# name                                                None
# screen_name                                         None
# location                                            None
# description                                         None
# url                                                 None
# entities                                            None
# protected                                           None
# followers_count                                     None
# friends_count                                       None
# listed_count                                        None
# created_at                                          None
# favourites_count                                    None
# utc_offset                                          None
# time_zone                                           None
# geo_enabled                                         None
# verified                                            None
# statuses_count                                      None
# lang                                                None
# contributors_enabled                                None
# is_translator                                       None
# is_translation_enabled                              None
# profile_background_color                            None
# profile_background_image_url                        None
# profile_background_image_url_https                  None
# profile_background_tile                             None
# profile_image_url                                   None
# profile_image_url_https                             None
# profile_banner_url                                  None
# profile_link_color                                  None
# profile_sidebar_border_color                        None
# profile_sidebar_fill_color                          None
# profile_text_color                                  None
# profile_use_background_image                        None
# has_extended_profile                                None
# default_profile                                     None
# default_profile_image                               None
# following                                           None
# follow_request_sent                                 None
# notifications                                       None
# translator_type                                     None
#
#                                    in_reply_to_status_id_str  \
# hashtags                                                None
# symbols                                                 None
# user_mentions                                           None
# urls                                                    None
# id                                                      None
# id_str                                                  None
# name                                                    None
# screen_name                                             None
# location                                                None
# description                                             None
# url                                                     None
# entities                                                None
# protected                                               None
# followers_count                                         None
# friends_count                                           None
# listed_count                                            None
# created_at                                              None
# favourites_count                                        None
# utc_offset                                              None
# time_zone                                               None
# geo_enabled                                             None
# verified                                                None
# statuses_count                                          None
# lang                                                    None
# contributors_enabled                                    None
# is_translator                                           None
# is_translation_enabled                                  None
# profile_background_color                                None
# profile_background_image_url                            None
# profile_background_image_url_https                      None
# profile_background_tile                                 None
# profile_image_url                                       None
# profile_image_url_https                                 None
# profile_banner_url                                      None
# profile_link_color                                      None
# profile_sidebar_border_color                            None
# profile_sidebar_fill_color                              None
# profile_text_color                                      None
# profile_use_background_image                            None
# has_extended_profile                                    None
# default_profile                                         None
# default_profile_image                                   None
# following                                               None
# follow_request_sent                                     None
# notifications                                           None
# translator_type                                         None
#
#                                    in_reply_to_user_id  ...   geo coordinates  \
# hashtags                                          None  ...  None        None
# symbols                                           None  ...  None        None
# user_mentions                                     None  ...  None        None
# urls                                              None  ...  None        None
# id                                                None  ...  None        None
# id_str                                            None  ...  None        None
# name                                              None  ...  None        None
# screen_name                                       None  ...  None        None
# location                                          None  ...  None        None
# description                                       None  ...  None        None
# url                                               None  ...  None        None
# entities                                          None  ...  None        None
# protected                                         None  ...  None        None
# followers_count                                   None  ...  None        None
# friends_count                                     None  ...  None        None
# listed_count                                      None  ...  None        None
# created_at                                        None  ...  None        None
# favourites_count                                  None  ...  None        None
# utc_offset                                        None  ...  None        None
# time_zone                                         None  ...  None        None
# geo_enabled                                       None  ...  None        None
# verified                                          None  ...  None        None
# statuses_count                                    None  ...  None        None
# lang                                              None  ...  None        None
# contributors_enabled                              None  ...  None        None
# is_translator                                     None  ...  None        None
# is_translation_enabled                            None  ...  None        None
# profile_background_color                          None  ...  None        None
# profile_background_image_url                      None  ...  None        None
# profile_background_image_url_https                None  ...  None        None
# profile_background_tile                           None  ...  None        None
# profile_image_url                                 None  ...  None        None
# profile_image_url_https                           None  ...  None        None
# profile_banner_url                                None  ...  None        None
# profile_link_color                                None  ...  None        None
# profile_sidebar_border_color                      None  ...  None        None
# profile_sidebar_fill_color                        None  ...  None        None
# profile_text_color                                None  ...  None        None
# profile_use_background_image                      None  ...  None        None
# has_extended_profile                              None  ...  None        None
# default_profile                                   None  ...  None        None
# default_profile_image                             None  ...  None        None
# following                                         None  ...  None        None
# follow_request_sent                               None  ...  None        None
# notifications                                     None  ...  None        None
# translator_type                                   None  ...  None        None
#
#                                    place contributors is_quote_status  \
# hashtags                            None         None           False
# symbols                             None         None           False
# user_mentions                       None         None           False
# urls                                None         None           False
# id                                  None         None           False
# id_str                              None         None           False
# name                                None         None           False
# screen_name                         None         None           False
# location                            None         None           False
# description                         None         None           False
# url                                 None         None           False
# entities                            None         None           False
# protected                           None         None           False
# followers_count                     None         None           False
# friends_count                       None         None           False
# listed_count                        None         None           False
# created_at                          None         None           False
# favourites_count                    None         None           False
# utc_offset                          None         None           False
# time_zone                           None         None           False
# geo_enabled                         None         None           False
# verified                            None         None           False
# statuses_count                      None         None           False
# lang                                None         None           False
# contributors_enabled                None         None           False
# is_translator                       None         None           False
# is_translation_enabled              None         None           False
# profile_background_color            None         None           False
# profile_background_image_url        None         None           False
# profile_background_image_url_https  None         None           False
# profile_background_tile             None         None           False
# profile_image_url                   None         None           False
# profile_image_url_https             None         None           False
# profile_banner_url                  None         None           False
# profile_link_color                  None         None           False
# profile_sidebar_border_color        None         None           False
# profile_sidebar_fill_color          None         None           False
# profile_text_color                  None         None           False
# profile_use_background_image        None         None           False
# has_extended_profile                None         None           False
# default_profile                     None         None           False
# default_profile_image               None         None           False
# following                           None         None           False
# follow_request_sent                 None         None           False
# notifications                       None         None           False
# translator_type                     None         None           False
#
#                                    retweet_count favorite_count  favorited  \
# hashtags                                   46551         178129      False
# symbols                                    46551         178129      False
# user_mentions                              46551         178129      False
# urls                                       46551         178129      False
# id                                         46551         178129      False
# id_str                                     46551         178129      False
# name                                       46551         178129      False
# screen_name                                46551         178129      False
# location                                   46551         178129      False
# description                                46551         178129      False
# url                                        46551         178129      False
# entities                                   46551         178129      False
# protected                                  46551         178129      False
# followers_count                            46551         178129      False
# friends_count                              46551         178129      False
# listed_count                               46551         178129      False
# created_at                                 46551         178129      False
# favourites_count                           46551         178129      False
# utc_offset                                 46551         178129      False
# time_zone                                  46551         178129      False
# geo_enabled                                46551         178129      False
# verified                                   46551         178129      False
# statuses_count                             46551         178129      False
# lang                                       46551         178129      False
# contributors_enabled                       46551         178129      False
# is_translator                              46551         178129      False
# is_translation_enabled                     46551         178129      False
# profile_background_color                   46551         178129      False
# profile_background_image_url               46551         178129      False
# profile_background_image_url_https         46551         178129      False
# profile_background_tile                    46551         178129      False
# profile_image_url                          46551         178129      False
# profile_image_url_https                    46551         178129      False
# profile_banner_url                         46551         178129      False
# profile_link_color                         46551         178129      False
# profile_sidebar_border_color               46551         178129      False
# profile_sidebar_fill_color                 46551         178129      False
# profile_text_color                         46551         178129      False
# profile_use_background_image               46551         178129      False
# has_extended_profile                       46551         178129      False
# default_profile                            46551         178129      False
# default_profile_image                      46551         178129      False
# following                                  46551         178129      False
# follow_request_sent                        46551         178129      False
# notifications                              46551         178129      False
# translator_type                            46551         178129      False
#
#                                     retweeted  lang
# hashtags                                False    en
# symbols                                 False    en
# user_mentions                           False    en
# urls                                    False    en
# id                                      False    en
# id_str                                  False    en
# name                                    False    en
# screen_name                             False    en
# location                                False    en
# description                             False    en
# url                                     False    en
# entities                                False    en
# protected                               False    en
# followers_count                         False    en
# friends_count                           False    en
# listed_count                            False    en
# created_at                              False    en
# favourites_count                        False    en
# utc_offset                              False    en
# time_zone                               False    en
# geo_enabled                             False    en
# verified                                False    en
# statuses_count                          False    en
# lang                                    False    en
# contributors_enabled                    False    en
# is_translator                           False    en
# is_translation_enabled                  False    en
# profile_background_color                False    en
# profile_background_image_url            False    en
# profile_background_image_url_https      False    en
# profile_background_tile                 False    en
# profile_image_url                       False    en
# profile_image_url_https                 False    en
# profile_banner_url                      False    en
# profile_link_color                      False    en
# profile_sidebar_border_color            False    en
# profile_sidebar_fill_color              False    en
# profile_text_color                      False    en
# profile_use_background_image            False    en
# has_extended_profile                    False    en
# default_profile                         False    en
# default_profile_image                   False    en
# following                               False    en
# follow_request_sent                     False    en
# notifications                           False    en
# translator_type                         False    en
#
# [46 rows x 23 columns]

# %%
# we'll take our results and turn them into a dataframe
results = pd.DataFrame({
    'name': [result['user']['name'] for result in tweet_results],
    'screen_name': [result['user']['screen_name'] for result in tweet_results],
    'text': [result['text'] for result in tweet_results],
    'retweets': [result['retweet_count'] for result in tweet_results],
    'favorites': [result['favorite_count'] for result in tweet_results],
    'id': [result['id_str'] for result in tweet_results]
})

print(f"API call brought in {results.shape[0]} new tweets")
results.head()
# Out:
# API call brought in 200 new tweets
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  Congratulations, the Moderna vaccine is now av...      8334      55602
# 1                            https://t.co/oMa4GS9q6K     37037     126120
# 2  THANK YOU to the GREAT men and women of @FedEx...     31455     211238
# 3  The Secretary of State and Governor of Georgia...     43659     150579
# 4  Governor @BrianKempGA of Georgia still has not...     39110     167805
#
#                     id
# 0  1340096386113687554
# 1  1339993708146683905
# 2  1339971240157736960
# 3  1339953001847525379
# 4  1339938332223139840

# %% [markdown]
# ### Step 3:  Checking For New Values

# %%
# this does a check for new values
# left merge means 'tweets' is the dominant table
# indicator lets you know if the value was present in one of the tables or both
results.merge(tweets, on='id', how='left', indicator=True)
# Out:
#               name_x    screen_name_x  \
# 0    Donald J. Trump  realDonaldTrump
# 1    Donald J. Trump  realDonaldTrump
# 2    Donald J. Trump  realDonaldTrump
# 3    Donald J. Trump  realDonaldTrump
# 4    Donald J. Trump  realDonaldTrump
# ..               ...              ...
# 195  Donald J. Trump  realDonaldTrump
# 196  Donald J. Trump  realDonaldTrump
# 197  Donald J. Trump  realDonaldTrump
# 198  Donald J. Trump  realDonaldTrump
# 199  Donald J. Trump  realDonaldTrump
#
#                                                 text_x  retweets_x  \
# 0    Congratulations, the Moderna vaccine is now av...        8334
# 1                              https://t.co/oMa4GS9q6K       37037
# 2    THANK YOU to the GREAT men and women of @FedEx...       31455
# 3    The Secretary of State and Governor of Georgia...       43659
# 4    Governor @BrianKempGA of Georgia still has not...       39110
# ..                                                 ...         ...
# 195  RT @WhiteHouse: "The plan we put forward prior...        9328
# 196  RT @WhiteHouse: "If authorized, tens of millio...        9008
# 197  RT @WhiteHouse: Before Operation Warp Speed, t...        7096
# 198  RT @WhiteHouse: "From the instant the Coronavi...        8161
# 199  RT @WhiteHouse: LIVE: Operation Warp Speed Vac...        8194
#
#      favorites_x                   id           name_y    screen_name_y  \
# 0          55602  1340096386113687554  Donald J. Trump  realDonaldTrump
# 1         126120  1339993708146683905  Donald J. Trump  realDonaldTrump
# 2         211238  1339971240157736960  Donald J. Trump  realDonaldTrump
# 3         150579  1339953001847525379  Donald J. Trump  realDonaldTrump
# 4         167805  1339938332223139840  Donald J. Trump  realDonaldTrump
# ..           ...                  ...              ...              ...
# 195            0  1336415114191400966  Donald J. Trump  realDonaldTrump
# 196            0  1336415090770399236  Donald J. Trump  realDonaldTrump
# 197            0  1336415057601761282  Donald J. Trump  realDonaldTrump
# 198            0  1336415036210864130  Donald J. Trump  realDonaldTrump
# 199            0  1336411597330391046  Donald J. Trump  realDonaldTrump
#
#                                                 text_y  retweets_y  \
# 0    Congratulations, the Moderna vaccine is now av...        5274
# 1                              https://t.co/oMa4GS9q6K        2211
# 2    THANK YOU to the GREAT men and women of @FedEx...        9451
# 3    The Secretary of State and Governor of Georgia...       15029
# 4    Governor @BrianKempGA of Georgia still has not...       12539
# ..                                                 ...         ...
# 195  RT @WhiteHouse: "The plan we put forward prior...         882
# 196  RT @WhiteHouse: "If authorized, tens of millio...         996
# 197  RT @WhiteHouse: Before Operation Warp Speed, t...         704
# 198  RT @WhiteHouse: "From the instant the Coronavi...        1095
# 199  RT @WhiteHouse: LIVE: Operation Warp Speed Vac...        2715
#
#      favorites_y _merge
# 0          32019   both
# 1           6485   both
# 2          56821   both
# 3          51065   both
# 4          50669   both
# ..           ...    ...
# 195            0   both
# 196            0   both
# 197            0   both
# 198            0   both
# 199            0   both
#
# [200 rows x 12 columns]

# %%
# we'll save the variable
merged_df = results.merge(tweets, on='id', how='left', indicator=True)

# %%
# select the values that are left_only in the _merge column -- these are new values
print(f"Found {merged_df[merged_df._merge == 'left_only'].shape[0]} new tweets not currently in the database")
merged_df[merged_df._merge == 'left_only']
# Out:
# Found 0 new tweets not currently in the database
# Empty DataFrame
# Columns: [name_x, screen_name_x, text_x, retweets_x, favorites_x, id, name_y, screen_name_y, text_y, retweets_y, favorites_y, _merge]
# Index: []

# %%
# get the index positions where this value is True
merged_df[merged_df._merge == 'left_only'].index
# Out:
# Int64Index([], dtype='int64')

# %%
results.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
# use these values to look up tweets in the original results df
idx = merged_df[merged_df._merge == 'left_only'].index
# and these are our new tweets
results.iloc[idx]
# Out:
#               name      screen_name  \
# 0  Donald J. Trump  realDonaldTrump
# 1  Donald J. Trump  realDonaldTrump
# 2  Donald J. Trump  realDonaldTrump
# 3  Donald J. Trump  realDonaldTrump
# 4  Donald J. Trump  realDonaldTrump
# 5  Donald J. Trump  realDonaldTrump
#
#                                                 text  retweets  favorites  \
# 0  RT @realDonaldTrump: VOTE! VOTE! VOTE!\nhttps:...    121165          0
# 1  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     14850          0
# 2  RT @realDonaldTrump: https://t.co/gsFSgh2KPc h...     11699          0
# 3  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     11580          0
# 4       RT @realDonaldTrump: https://t.co/voxNnIYMpe      8901          0
# 5  RT @realDonaldTrump: https://t.co/gsFSghkmdM h...     13069          0
#
#                     id
# 0  1323714481353068546
# 1  1323714393184653323
# 2  1323714331922583556
# 3  1323714155967373312
# 4  1323714095225384962
# 5  1323713956280754182

# %%
# and now we'll connect to the database and add in the values
with engine.connect() as connection:
    # declare data types for the db -- not necessary but a useful step if you are doing this the first time
    dtypes = {
        'name': types.String(length=65535),
        'screen_name': types.String(length=65535),
        'text': types.String(length=65535),
        'retweets': types.Integer(),
        'favorites': types.Integer(),
        'id': types.String(length=65535)
    }
    print("Adding values to database")
    try:
        results.iloc[idx].to_sql('tweets', con=connection, index=False, if_exists='append', dtype=dtypes)
        print("Successful")
    except Exception as e:
        print("Could not add results to the database.", e)
# Out:
# Adding values to database
# Successful
